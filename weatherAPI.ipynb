# %%
# Dependencies

import csv
import matplotlib.pyplot as plt
import requests as req
import pandas as pd
import numpy as np
import time
#from config import api_key
import json

api_key = "e2a9a922fc404b7c173aefab7a12ada0"


# Output File (CSV)
output_data_file = "citipy-0.0.5/citipy/worldcities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

coordinates = []
lat = np.random.uniform

# %%
# Incorporated citipy to determine city based on latitude and longitude


import sys
print(sys.path)

sys.path.append("/Users/paulaamandagallardo/anaconda3/lib/python3.6/site-packages")

from citipy import citipy
# Out:
# ['', '/Users/paulaamandagallardo/anaconda3/envs/PythonData/lib/python36.zip', '/Users/paulaamandagallardo/anaconda3/envs/PythonData/lib/python3.6', '/Users/paulaamandagallardo/anaconda3/envs/PythonData/lib/python3.6/lib-dynload', '/Users/paulaamandagallardo/anaconda3/envs/PythonData/lib/python3.6/site-packages', '/Users/paulaamandagallardo/anaconda3/envs/PythonData/lib/python3.6/site-packages/aeosa', '/Users/paulaamandagallardo/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/extensions', '/Users/paulaamandagallardo/.ipython', './anaconda3/lib/python3.6/site-packages', '/Users/paulaamandagallardo/anaconda3/lib/python3.6/site-packages', '/Users/paulaamandagallardo/anaconda3/lib/python3.6/site-packages', '/Users/paulaamandagallardo/anaconda3/lib/python3.6/site-packages']

# %%
#Read csv File 
data_file_pd = pd.read_csv(output_data_file)
data_file_pd.head()
# Out:
#   Country              City   Latitude  Longitude
# 0      ad  andorra la vella  42.500000   1.516667
# 1      ad           canillo  42.566667   1.600000
# 2      ad            encamp  42.533333   1.583333
# 3      ad        la massana  42.550000   1.516667
# 4      ad      les escaldes  42.500000   1.533333

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1])
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"


# Build query URL
query_url = url + "appid=" + api_key + "&units=" + units + "&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q='

# %%
#Generate weather data list by API calls
print("Beginning Data Retrieval\n------------------------------------------")
weather_data=[]
counter=0
set=1
for i, city in enumerate (cities):
    data = req.get(query_url + city.city_name).json()
    print("Processing Record "+ str(i+1) + " of Set " + str(set) + "|" + city.city_name )
    print(query_url+ city.city_name)
    weather_data.append(data)
    counter+=1
    if counter==49:
        time.sleep(3)
        set+=1
        counter=0
print("------------------------------------------")
print("Data Retrieval Complete\n------------------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------------------
# Processing Record 1 of Set 1|clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=clyde river
# Processing Record 2 of Set 1|mao
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mao
# Processing Record 3 of Set 1|rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=rikitea
# Processing Record 4 of Set 1|tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tsihombe
# Processing Record 5 of Set 1|marathon
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=marathon
# Processing Record 6 of Set 1|ngerengere
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ngerengere
# Processing Record 7 of Set 1|saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=saskylakh
# Processing Record 8 of Set 1|albany
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=albany
# Processing Record 9 of Set 1|busselton
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=busselton
# Processing Record 10 of Set 1|inhuma
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=inhuma
# Processing Record 11 of Set 1|bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bredasdorp
# Processing Record 12 of Set 1|vaini
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=vaini
# Processing Record 13 of Set 1|bluff
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bluff
# Processing Record 14 of Set 1|upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=upernavik
# Processing Record 15 of Set 1|san vicente
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=san vicente
# Processing Record 16 of Set 1|torbay
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=torbay
# Processing Record 17 of Set 1|ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ushuaia
# Processing Record 18 of Set 1|billings
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=billings
# Processing Record 19 of Set 1|belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=belushya guba
# Processing Record 20 of Set 1|georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=georgetown
# Processing Record 21 of Set 1|broome
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=broome
# Processing Record 22 of Set 1|belmonte
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=belmonte
# Processing Record 23 of Set 1|mataura
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mataura
# Processing Record 24 of Set 1|red bluff
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=red bluff
# Processing Record 25 of Set 1|narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=narsaq
# Processing Record 26 of Set 1|mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mar del plata
# Processing Record 27 of Set 1|tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tuktoyaktuk
# Processing Record 28 of Set 1|atuona
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=atuona
# Processing Record 29 of Set 1|cape town
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=cape town
# Processing Record 30 of Set 1|ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ilulissat
# Processing Record 31 of Set 1|avarua
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=avarua
# Processing Record 32 of Set 1|pimentel
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=pimentel
# Processing Record 33 of Set 1|san jose
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=san jose
# Processing Record 34 of Set 1|barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=barentsburg
# Processing Record 35 of Set 1|dicabisagan
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=dicabisagan
# Processing Record 36 of Set 1|pisco
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=pisco
# Processing Record 37 of Set 1|babanusah
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=babanusah
# Processing Record 38 of Set 1|castro
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=castro
# Processing Record 39 of Set 1|vigrestad
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=vigrestad
# Processing Record 40 of Set 1|college
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=college
# Processing Record 41 of Set 1|taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=taolanaro
# Processing Record 42 of Set 1|hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=hermanus
# Processing Record 43 of Set 1|kuala terengganu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kuala terengganu
# Processing Record 44 of Set 1|svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=svetlogorsk
# Processing Record 45 of Set 1|tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tasiilaq
# Processing Record 46 of Set 1|manaure
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=manaure
# Processing Record 47 of Set 1|norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=norman wells
# Processing Record 48 of Set 1|kabanjahe
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kabanjahe
# Processing Record 49 of Set 1|tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tiksi
# Processing Record 50 of Set 2|faanui
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=faanui
# Processing Record 51 of Set 2|houma
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=houma
# Processing Record 52 of Set 2|norwood
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=norwood
# Processing Record 53 of Set 2|kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kavaratti
# Processing Record 54 of Set 2|mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mys shmidta
# Processing Record 55 of Set 2|ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ribeira grande
# Processing Record 56 of Set 2|saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=saint-augustin
# Processing Record 57 of Set 2|ayolas
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ayolas
# Processing Record 58 of Set 2|micheweni
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=micheweni
# Processing Record 59 of Set 2|aswan
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=aswan
# Processing Record 60 of Set 2|bon air
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bon air
# Processing Record 61 of Set 2|ranghulu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ranghulu
# Processing Record 62 of Set 2|luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=luderitz
# Processing Record 63 of Set 2|cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=cherskiy
# Processing Record 64 of Set 2|san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=san patricio
# Processing Record 65 of Set 2|provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=provideniya
# Processing Record 66 of Set 2|karratha
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=karratha
# Processing Record 67 of Set 2|puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=puerto ayora
# Processing Record 68 of Set 2|vao
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=vao
# Processing Record 69 of Set 2|east london
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=east london
# Processing Record 70 of Set 2|tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tuatapere
# Processing Record 71 of Set 2|madang
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=madang
# Processing Record 72 of Set 2|moerai
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=moerai
# Processing Record 73 of Set 2|biala podlaska
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=biala podlaska
# Processing Record 74 of Set 2|shimoda
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=shimoda
# Processing Record 75 of Set 2|punta alta
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=punta alta
# Processing Record 76 of Set 2|ancud
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ancud
# Processing Record 77 of Set 2|kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kaitangata
# Processing Record 78 of Set 2|guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=guerrero negro
# Processing Record 79 of Set 2|sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=sinnamary
# Processing Record 80 of Set 2|salalah
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=salalah
# Processing Record 81 of Set 2|ziro
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ziro
# Processing Record 82 of Set 2|chemal
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=chemal
# Processing Record 83 of Set 2|nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nikolskoye
# Processing Record 84 of Set 2|kutum
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kutum
# Processing Record 85 of Set 2|soluno-dmitriyevskoye
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=soluno-dmitriyevskoye
# Processing Record 86 of Set 2|yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=yellowknife
# Processing Record 87 of Set 2|san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=san cristobal
# Processing Record 88 of Set 2|barcelos
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=barcelos
# Processing Record 89 of Set 2|petropavlovka
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=petropavlovka
# Processing Record 90 of Set 2|lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=lincoln
# Processing Record 91 of Set 2|port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=port elizabeth
# Processing Record 92 of Set 2|nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nizhneyansk
# Processing Record 93 of Set 2|yinchuan
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=yinchuan
# Processing Record 94 of Set 2|attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=attawapiskat
# Processing Record 95 of Set 2|nantucket
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nantucket
# Processing Record 96 of Set 2|rosarito
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=rosarito
# Processing Record 97 of Set 2|almaznyy
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=almaznyy
# Processing Record 98 of Set 2|nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nanortalik
# Processing Record 99 of Set 3|xichang
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=xichang
# Processing Record 100 of Set 3|opuwo
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=opuwo
# Processing Record 101 of Set 3|tir pol
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tir pol
# Processing Record 102 of Set 3|kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kruisfontein
# Processing Record 103 of Set 3|kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kodiak
# Processing Record 104 of Set 3|labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=labuhan
# Processing Record 105 of Set 3|waddan
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=waddan
# Processing Record 106 of Set 3|airai
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=airai
# Processing Record 107 of Set 3|kjopsvik
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kjopsvik
# Processing Record 108 of Set 3|moanda
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=moanda
# Processing Record 109 of Set 3|lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=lorengau
# Processing Record 110 of Set 3|jonava
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=jonava
# Processing Record 111 of Set 3|severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=severo-kurilsk
# Processing Record 112 of Set 3|victor harbor
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=victor harbor
# Processing Record 113 of Set 3|znamenskoye
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=znamenskoye
# Processing Record 114 of Set 3|geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=geraldton
# Processing Record 115 of Set 3|belyy yar
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=belyy yar
# Processing Record 116 of Set 3|cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=cabo san lucas
# Processing Record 117 of Set 3|namatanai
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=namatanai
# Processing Record 118 of Set 3|zheleznodorozhnyy
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=zheleznodorozhnyy
# Processing Record 119 of Set 3|durant
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=durant
# Processing Record 120 of Set 3|balkanabat
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=balkanabat
# Processing Record 121 of Set 3|san rafael del sur
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=san rafael del sur
# Processing Record 122 of Set 3|saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=saint-pierre
# Processing Record 123 of Set 3|san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=san quintin
# Processing Record 124 of Set 3|esperance
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=esperance
# Processing Record 125 of Set 3|port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=port alfred
# Processing Record 126 of Set 3|sitka
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=sitka
# Processing Record 127 of Set 3|lolua
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=lolua
# Processing Record 128 of Set 3|umzimvubu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=umzimvubu
# Processing Record 129 of Set 3|rorvik
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=rorvik
# Processing Record 130 of Set 3|thompson
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=thompson
# Processing Record 131 of Set 3|santa maria
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=santa maria
# Processing Record 132 of Set 3|ngukurr
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ngukurr
# Processing Record 133 of Set 3|melfi
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=melfi
# Processing Record 134 of Set 3|chuy
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=chuy
# Processing Record 135 of Set 3|luganville
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=luganville
# Processing Record 136 of Set 3|jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=jamestown
# Processing Record 137 of Set 3|hilo
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=hilo
# Processing Record 138 of Set 3|bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bambous virieux
# Processing Record 139 of Set 3|barrow
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=barrow
# Processing Record 140 of Set 3|kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kapaa
# Processing Record 141 of Set 3|anakapalle
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=anakapalle
# Processing Record 142 of Set 3|khandyga
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=khandyga
# Processing Record 143 of Set 3|tabou
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tabou
# Processing Record 144 of Set 3|saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=saint-philippe
# Processing Record 145 of Set 3|hobart
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=hobart
# Processing Record 146 of Set 3|victoria
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=victoria
# Processing Record 147 of Set 3|amderma
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=amderma
# Processing Record 148 of Set 4|porirua
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=porirua
# Processing Record 149 of Set 4|khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=khatanga
# Processing Record 150 of Set 4|westport
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=westport
# Processing Record 151 of Set 4|hervey bay
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=hervey bay
# Processing Record 152 of Set 4|paita
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=paita
# Processing Record 153 of Set 4|dikson
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=dikson
# Processing Record 154 of Set 4|nabire
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nabire
# Processing Record 155 of Set 4|aliaga
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=aliaga
# Processing Record 156 of Set 4|klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=klaksvik
# Processing Record 157 of Set 4|new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=new norfolk
# Processing Record 158 of Set 4|coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=coquimbo
# Processing Record 159 of Set 4|doha
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=doha
# Processing Record 160 of Set 4|punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=punta arenas
# Processing Record 161 of Set 4|butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=butaritari
# Processing Record 162 of Set 4|lashio
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=lashio
# Processing Record 163 of Set 4|hofn
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=hofn
# Processing Record 164 of Set 4|illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=illoqqortoormiut
# Processing Record 165 of Set 4|cervo
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=cervo
# Processing Record 166 of Set 4|verkh-usugli
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=verkh-usugli
# Processing Record 167 of Set 4|bam
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bam
# Processing Record 168 of Set 4|vracov
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=vracov
# Processing Record 169 of Set 4|wahiawa
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=wahiawa
# Processing Record 170 of Set 4|atambua
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=atambua
# Processing Record 171 of Set 4|bozovici
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bozovici
# Processing Record 172 of Set 4|savannah bight
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=savannah bight
# Processing Record 173 of Set 4|nishihara
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nishihara
# Processing Record 174 of Set 4|palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=palabuhanratu
# Processing Record 175 of Set 4|chicama
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=chicama
# Processing Record 176 of Set 4|retiro
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=retiro
# Processing Record 177 of Set 4|poum
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=poum
# Processing Record 178 of Set 4|ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ponta do sol
# Processing Record 179 of Set 4|luwuk
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=luwuk
# Processing Record 180 of Set 4|grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=grand river south east
# Processing Record 181 of Set 4|cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=cayenne
# Processing Record 182 of Set 4|trelew
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=trelew
# Processing Record 183 of Set 4|bonthe
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bonthe
# Processing Record 184 of Set 4|atar
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=atar
# Processing Record 185 of Set 4|kimbe
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kimbe
# Processing Record 186 of Set 4|aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=aklavik
# Processing Record 187 of Set 4|lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=lagoa
# Processing Record 188 of Set 4|rabo de peixe
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=rabo de peixe
# Processing Record 189 of Set 4|helong
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=helong
# Processing Record 190 of Set 4|kropotkin
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kropotkin
# Processing Record 191 of Set 4|cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=cidreira
# Processing Record 192 of Set 4|qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=qaanaaq
# Processing Record 193 of Set 4|souillac
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=souillac
# Processing Record 194 of Set 4|jos
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=jos
# Processing Record 195 of Set 4|paamiut
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=paamiut
# Processing Record 196 of Set 4|dibaya
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=dibaya
# Processing Record 197 of Set 5|sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=sentyabrskiy
# Processing Record 198 of Set 5|wattegama
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=wattegama
# Processing Record 199 of Set 5|leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=leningradskiy
# Processing Record 200 of Set 5|gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=gornopravdinsk
# Processing Record 201 of Set 5|puksoozero
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=puksoozero
# Processing Record 202 of Set 5|kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kavieng
# Processing Record 203 of Set 5|oriximina
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=oriximina
# Processing Record 204 of Set 5|grafton
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=grafton
# Processing Record 205 of Set 5|hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=hithadhoo
# Processing Record 206 of Set 5|norrtalje
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=norrtalje
# Processing Record 207 of Set 5|saleaula
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=saleaula
# Processing Record 208 of Set 5|fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=fairbanks
# Processing Record 209 of Set 5|tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tilichiki
# Processing Record 210 of Set 5|ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ahipara
# Processing Record 211 of Set 5|burnie
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=burnie
# Processing Record 212 of Set 5|baykit
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=baykit
# Processing Record 213 of Set 5|fengrun
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=fengrun
# Processing Record 214 of Set 5|kieta
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kieta
# Processing Record 215 of Set 5|prince rupert
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=prince rupert
# Processing Record 216 of Set 5|gisborne
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=gisborne
# Processing Record 217 of Set 5|sabang
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=sabang
# Processing Record 218 of Set 5|mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mahebourg
# Processing Record 219 of Set 5|nanchang
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nanchang
# Processing Record 220 of Set 5|richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=richards bay
# Processing Record 221 of Set 5|lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=lavrentiya
# Processing Record 222 of Set 5|andilamena
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=andilamena
# Processing Record 223 of Set 5|bethel
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bethel
# Processing Record 224 of Set 5|severnyy
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=severnyy
# Processing Record 225 of Set 5|lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=lompoc
# Processing Record 226 of Set 5|doka
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=doka
# Processing Record 227 of Set 5|visnes
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=visnes
# Processing Record 228 of Set 5|atasu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=atasu
# Processing Record 229 of Set 5|pevek
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=pevek
# Processing Record 230 of Set 5|bara
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bara
# Processing Record 231 of Set 5|turbat
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=turbat
# Processing Record 232 of Set 5|port hawkesbury
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=port hawkesbury
# Processing Record 233 of Set 5|marrakesh
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=marrakesh
# Processing Record 234 of Set 5|sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=sao joao da barra
# Processing Record 235 of Set 5|bargal
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bargal
# Processing Record 236 of Set 5|cockburn harbour
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=cockburn harbour
# Processing Record 237 of Set 5|fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=fortuna
# Processing Record 238 of Set 5|andenes
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=andenes
# Processing Record 239 of Set 5|walla walla
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=walla walla
# Processing Record 240 of Set 5|pauini
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=pauini
# Processing Record 241 of Set 5|half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=half moon bay
# Processing Record 242 of Set 5|kharitonovo
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kharitonovo
# Processing Record 243 of Set 5|tobol
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tobol
# Processing Record 244 of Set 5|taltal
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=taltal
# Processing Record 245 of Set 5|auburn
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=auburn
# Processing Record 246 of Set 6|kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kununurra
# Processing Record 247 of Set 6|chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=chokurdakh
# Processing Record 248 of Set 6|srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=srednekolymsk
# Processing Record 249 of Set 6|egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=egvekinot
# Processing Record 250 of Set 6|vaitupu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=vaitupu
# Processing Record 251 of Set 6|raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=raudeberg
# Processing Record 252 of Set 6|champerico
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=champerico
# Processing Record 253 of Set 6|anadyr
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=anadyr
# Processing Record 254 of Set 6|kyzyl-suu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kyzyl-suu
# Processing Record 255 of Set 6|ambodifototra
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ambodifototra
# Processing Record 256 of Set 6|sfantu gheorghe
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=sfantu gheorghe
# Processing Record 257 of Set 6|toba
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=toba
# Processing Record 258 of Set 6|badami
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=badami
# Processing Record 259 of Set 6|iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=iqaluit
# Processing Record 260 of Set 6|alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=alta floresta
# Processing Record 261 of Set 6|torit
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=torit
# Processing Record 262 of Set 6|carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=carnarvon
# Processing Record 263 of Set 6|santiago del estero
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=santiago del estero
# Processing Record 264 of Set 6|birin
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=birin
# Processing Record 265 of Set 6|shelburne
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=shelburne
# Processing Record 266 of Set 6|nemuro
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nemuro
# Processing Record 267 of Set 6|laguna
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=laguna
# Processing Record 268 of Set 6|sao pedro do sul
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=sao pedro do sul
# Processing Record 269 of Set 6|puerto escondido
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=puerto escondido
# Processing Record 270 of Set 6|savyntsi
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=savyntsi
# Processing Record 271 of Set 6|santa cruz de tenerife
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=santa cruz de tenerife
# Processing Record 272 of Set 6|changping
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=changping
# Processing Record 273 of Set 6|ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ketchikan
# Processing Record 274 of Set 6|taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=taoudenni
# Processing Record 275 of Set 6|nuuk
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nuuk
# Processing Record 276 of Set 6|bridlington
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bridlington
# Processing Record 277 of Set 6|vardo
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=vardo
# Processing Record 278 of Set 6|lichinga
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=lichinga
# Processing Record 279 of Set 6|mangai
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mangai
# Processing Record 280 of Set 6|rawson
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=rawson
# Processing Record 281 of Set 6|burica
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=burica
# Processing Record 282 of Set 6|lebu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=lebu
# Processing Record 283 of Set 6|talin
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=talin
# Processing Record 284 of Set 6|gushikawa
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=gushikawa
# Processing Record 285 of Set 6|jalu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=jalu
# Processing Record 286 of Set 6|coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=coihaique
# Processing Record 287 of Set 6|alofi
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=alofi
# Processing Record 288 of Set 6|natal
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=natal
# Processing Record 289 of Set 6|kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kloulklubed
# Processing Record 290 of Set 6|cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=cockburn town
# Processing Record 291 of Set 6|banda aceh
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=banda aceh
# Processing Record 292 of Set 6|montenegro
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=montenegro
# Processing Record 293 of Set 6|gold coast
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=gold coast
# Processing Record 294 of Set 6|kokstad
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kokstad
# Processing Record 295 of Set 7|caruray
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=caruray
# Processing Record 296 of Set 7|tsienyane
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tsienyane
# Processing Record 297 of Set 7|bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bengkulu
# Processing Record 298 of Set 7|barcelona
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=barcelona
# Processing Record 299 of Set 7|laibin
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=laibin
# Processing Record 300 of Set 7|vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=vila franca do campo
# Processing Record 301 of Set 7|deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=deputatskiy
# Processing Record 302 of Set 7|batsfjord
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=batsfjord
# Processing Record 303 of Set 7|ankpa
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ankpa
# Processing Record 304 of Set 7|chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=chernyshevskiy
# Processing Record 305 of Set 7|skibbereen
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=skibbereen
# Processing Record 306 of Set 7|galesong
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=galesong
# Processing Record 307 of Set 7|palmer
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=palmer
# Processing Record 308 of Set 7|taos
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=taos
# Processing Record 309 of Set 7|paracatu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=paracatu
# Processing Record 310 of Set 7|yirol
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=yirol
# Processing Record 311 of Set 7|roald
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=roald
# Processing Record 312 of Set 7|amapa
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=amapa
# Processing Record 313 of Set 7|viligili
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=viligili
# Processing Record 314 of Set 7|codrington
# ...
# Processing Record 513 of Set 11|rungata
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=rungata
# Processing Record 514 of Set 11|nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nouadhibou
# Processing Record 515 of Set 11|yakeshi
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=yakeshi
# Processing Record 516 of Set 11|minot
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=minot
# Processing Record 517 of Set 11|aflu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=aflu
# Processing Record 518 of Set 11|bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bandarbeyla
# Processing Record 519 of Set 11|sobolevo
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=sobolevo
# Processing Record 520 of Set 11|necochea
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=necochea
# Processing Record 521 of Set 11|alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=alice springs
# Processing Record 522 of Set 11|korla
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=korla
# Processing Record 523 of Set 11|leshan
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=leshan
# Processing Record 524 of Set 11|bata
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=bata
# Processing Record 525 of Set 11|mecca
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mecca
# Processing Record 526 of Set 11|caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=caravelas
# Processing Record 527 of Set 11|azuaga
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=azuaga
# Processing Record 528 of Set 11|fort saint john
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=fort saint john
# Processing Record 529 of Set 11|alamogordo
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=alamogordo
# Processing Record 530 of Set 11|port macquarie
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=port macquarie
# Processing Record 531 of Set 11|srandakan
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=srandakan
# Processing Record 532 of Set 11|ishurdi
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ishurdi
# Processing Record 533 of Set 11|mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mount gambier
# Processing Record 534 of Set 11|manubul
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=manubul
# Processing Record 535 of Set 11|parsabad
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=parsabad
# Processing Record 536 of Set 11|sorvag
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=sorvag
# Processing Record 537 of Set 11|longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=longyearbyen
# Processing Record 538 of Set 11|hirara
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=hirara
# Processing Record 539 of Set 11|tatawin
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tatawin
# Processing Record 540 of Set 12|tura
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tura
# Processing Record 541 of Set 12|pavino
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=pavino
# Processing Record 542 of Set 12|yulara
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=yulara
# Processing Record 543 of Set 12|leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=leshukonskoye
# Processing Record 544 of Set 12|novoagansk
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=novoagansk
# Processing Record 545 of Set 12|tchaourou
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=tchaourou
# Processing Record 546 of Set 12|luena
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=luena
# Processing Record 547 of Set 12|naze
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=naze
# Processing Record 548 of Set 12|ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ambilobe
# Processing Record 549 of Set 12|reconquista
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=reconquista
# Processing Record 550 of Set 12|ende
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ende
# Processing Record 551 of Set 12|mandalgovi
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mandalgovi
# Processing Record 552 of Set 12|mukhen
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mukhen
# Processing Record 553 of Set 12|kalvarija
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kalvarija
# Processing Record 554 of Set 12|verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=verkhoyansk
# Processing Record 555 of Set 12|toliary
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=toliary
# Processing Record 556 of Set 12|sumbe
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=sumbe
# Processing Record 557 of Set 12|mvomero
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mvomero
# Processing Record 558 of Set 12|manati
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=manati
# Processing Record 559 of Set 12|awbari
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=awbari
# Processing Record 560 of Set 12|westport
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=westport
# Processing Record 561 of Set 12|hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=hamilton
# Processing Record 562 of Set 12|najran
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=najran
# Processing Record 563 of Set 12|warqla
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=warqla
# Processing Record 564 of Set 12|grand-santi
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=grand-santi
# Processing Record 565 of Set 12|vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=vila velha
# Processing Record 566 of Set 12|kidal
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kidal
# Processing Record 567 of Set 12|linjiang
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=linjiang
# Processing Record 568 of Set 12|lityn
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=lityn
# Processing Record 569 of Set 12|jibuti
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=jibuti
# Processing Record 570 of Set 12|heinola
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=heinola
# Processing Record 571 of Set 12|ossora
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ossora
# Processing Record 572 of Set 12|wanning
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=wanning
# Processing Record 573 of Set 12|aksu
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=aksu
# Processing Record 574 of Set 12|olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=olafsvik
# Processing Record 575 of Set 12|iskateley
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=iskateley
# Processing Record 576 of Set 12|zaranj
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=zaranj
# Processing Record 577 of Set 12|lasa
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=lasa
# Processing Record 578 of Set 12|nichinan
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nichinan
# Processing Record 579 of Set 12|jizan
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=jizan
# Processing Record 580 of Set 12|fort nelson
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=fort nelson
# Processing Record 581 of Set 12|mayya
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mayya
# Processing Record 582 of Set 12|nenjiang
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nenjiang
# Processing Record 583 of Set 12|lamar
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=lamar
# Processing Record 584 of Set 12|oksfjord
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=oksfjord
# Processing Record 585 of Set 12|birao
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=birao
# Processing Record 586 of Set 12|kamenka
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kamenka
# Processing Record 587 of Set 12|harper
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=harper
# Processing Record 588 of Set 12|pipar
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=pipar
# Processing Record 589 of Set 13|chugunash
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=chugunash
# Processing Record 590 of Set 13|cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=cap malheureux
# Processing Record 591 of Set 13|rawatbhata
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=rawatbhata
# Processing Record 592 of Set 13|himora
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=himora
# Processing Record 593 of Set 13|borisoglebskiy
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=borisoglebskiy
# Processing Record 594 of Set 13|magdalena
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=magdalena
# Processing Record 595 of Set 13|altay
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=altay
# Processing Record 596 of Set 13|aqtobe
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=aqtobe
# Processing Record 597 of Set 13|sergeyevka
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=sergeyevka
# Processing Record 598 of Set 13|ranot
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ranot
# Processing Record 599 of Set 13|brae
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=brae
# Processing Record 600 of Set 13|ayagoz
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ayagoz
# Processing Record 601 of Set 13|vagur
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=vagur
# Processing Record 602 of Set 13|saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=saldanha
# Processing Record 603 of Set 13|vikesa
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=vikesa
# Processing Record 604 of Set 13|kaeo
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=kaeo
# Processing Record 605 of Set 13|mazamet
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=mazamet
# Processing Record 606 of Set 13|xinmin
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=xinmin
# Processing Record 607 of Set 13|springdale
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=springdale
# Processing Record 608 of Set 13|ulladulla
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=ulladulla
# Processing Record 609 of Set 13|beloha
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=beloha
# Processing Record 610 of Set 13|arenapolis
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=arenapolis
# Processing Record 611 of Set 13|planaltina
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=planaltina
# Processing Record 612 of Set 13|dunda
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=dunda
# Processing Record 613 of Set 13|loubomo
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=loubomo
# Processing Record 614 of Set 13|margate
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=margate
# Processing Record 615 of Set 13|nyrob
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=nyrob
# Processing Record 616 of Set 13|paicol
# http://api.openweathermap.org/data/2.5/weather?appid=e2a9a922fc404b7c173aefab7a12ada0&units=Imperial&q=paicol
# ------------------------------------------
# Data Retrieval Complete
# ------------------------------------------

# %%
# Get weather data
#weather_response = requests.get(query_url)
#weather_json = weather_response.json()

# Get the temperature from the response
#print(f"The weather API responded with: {weather_json}.")

#Display an example data
weather_data[0]
# Out:
# {'coord': {'lon': -68.59, 'lat': 70.47},
#  'weather': [{'id': 600,
#    'main': 'Snow',
#    'description': 'light snow',
#    'icon': '13n'}],
#  'base': 'stations',
#  'main': {'temp': 14,
#   'pressure': 1019,
#   'humidity': 92,
#   'temp_min': 14,
#   'temp_max': 14},
#  'visibility': 1609,
#  'wind': {'speed': 31.09, 'deg': 310},
#  'clouds': {'all': 90},
#  'dt': 1540296660,
#  'sys': {'type': 1,
#   'id': 3585,
#   'message': 0.0061,
#   'country': 'CA',
#   'sunrise': 1540297723,
#   'sunset': 1540325212},
#  'id': 5924351,
#  'name': 'Clyde River',
#  'cod': 200}

# %%
#Generate the data lists
city_name=[]
country_code=[]
date=[]
lat_data=[]
lon_data=[]
clouds_data=[]
humidity_data=[]
temp_data=[]
wind_data=[]
for data in weather_data:
    try:
       # country_code.append(data.get("sys").get("country"))
        
        country_code.append(data["sys"]["country"])
        city_name.append(data["name"])
        date.append(data["dt"]) 
        lat_data.append(data["coord"]["lat"])
        lon_data.append(data["coord"]["lon"]) 
        clouds_data.append(data['clouds']["all"]) 
        humidity_data.append(data['main']['humidity']) 
        temp_data.append(data['main']['temp_max']) 
        wind_data.append(data['wind']['speed']) 
    except:
        print("Skipping invalid data")
        continue

#Generate a dataframe to include the data
city_data = {"City": city_name, "Country": country_code,"Date":date, "Lat": lat_data, "Lng": lon_data, "Max Temp":temp_data,
               "Cloudiness": clouds_data, "Humidity": humidity_data, "Wind Speed": wind_data}
city_data = pd.DataFrame(city_data)
city_data.head()
# Out:
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
# Skipping invalid data
#           City Country        Date    Lat     Lng  Max Temp  Cloudiness  \
# 0  Clyde River      CA  1540296660  70.47  -68.59      14.0          90
# 1          Mao      DO  1540296000  19.55  -71.08      73.4          20
# 2      Rikitea      PF  1540297547 -23.12 -134.97      70.1         100
# 3     Marathon      CA  1540296000  48.72  -86.38      33.8          75
# 4   Ngerengere      TZ  1540296000  -6.76   38.13      86.0          40
#
#    Humidity  Wind Speed
# 0        92       31.09
# 1       100        7.52
# 2       100        3.49
# 3        86       19.46
# 4        42        7.96

# %%
#Display the dataframe info
city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551 entries, 0 to 550
# Data columns (total 9 columns):
# City          551 non-null object
# Country       551 non-null object
# Date          551 non-null int64
# Lat           551 non-null float64
# Lng           551 non-null float64
# Max Temp      551 non-null float64
# Cloudiness    551 non-null int64
# Humidity      551 non-null int64
# Wind Speed    551 non-null float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 38.8+ KB

# %%
# Build a scatter plot for each data type
plt.figure(figsize=(8,6))
plt.scatter(city_data["Lat"], city_data["Max Temp"], marker="o", color='navy', edgecolor="black")

# Incorporate the other graph properties
plt.xlim(-80,100) #params: min to max lat 
plt.ylim(0, 120) 
plt.title("City Latitude vs Max Temperature (10/13/2018)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("MaxTemp.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.figure(figsize=(8,6))
plt.scatter(city_data["Lat"], city_data["Humidity"], marker="o",color='navy', edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity (10/13/2018)")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Humidity.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.figure(figsize=(8,6))
plt.scatter(city_data["Lat"], city_data["Cloudiness"], marker="o", color='navy', edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness (10/13/2018)")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.figure(figsize=(8,6))
plt.scatter(city_data["Lat"], city_data["Wind Speed"], marker="o", color='navy', edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (10/13/2018)")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindSpeed.png")

# Show plot
plt.show()

# %%
# Save the dataframe as csv file
city_data.to_csv("city_data.csv")

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-5b9d5bed61de> in <module>()
#      10 # Identify nearest city for each lat, lng combination
#      11 for lat_lng in lat_lngs:
# ---> 12    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
#      13
#      14    # If the city is unique, then add it to a our cities list
#
# NameError: name 'citipy' is not defined

# %%
The weather API responded with: {'coord': {'lon': -0.13, 'lat': 51.51}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}, {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 277.48, 'pressure': 1026, 'humidity': 86, 'temp_min': 277.15, 'temp_max': 278.15}, 'visibility': 5000, 'wind': {'speed': 2.1, 'deg': 360}, 'clouds': {'all': 90}, 'dt': 1519240800, 'sys': {'type': 1, 'id': 5093, 'message': 0.0062, 'country': 'GB', 'sunrise': 1519196463, 'sunset': 1519234070}, 'id': 2643743, 'name': 'London', 'cod': 200}.
# Out:
#   File "<ipython-input-9-0f115c60c204>", line 1
#     The weather API responded with: {'coord': {'lon': -0.13, 'lat': 51.51}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}, {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 277.48, 'pressure': 1026, 'humidity': 86, 'temp_min': 277.15, 'temp_max': 278.15}, 'visibility': 5000, 'wind': {'speed': 2.1, 'deg': 360}, 'clouds': {'all': 90}, 'dt': 1519240800, 'sys': {'type': 1, 'id': 5093, 'message': 0.0062, 'country': 'GB', 'sunrise': 1519196463, 'sunset': 1519234070}, 'id': 2643743, 'name': 'London', 'cod': 200}.
#               ^
# SyntaxError: invalid syntax

# %%
WeatherPy

In this example, you'll be creating a Python script to visualize the weather of 500+ cities 
across the world of varying distance from the equator. To accomplish this, you'll be utilizing
a simple Python library, the OpenWeatherMap API, and a little common sense to create a representative 
model of weather across world cities.

Your objective is to build a series of scatter plots to showcase the following relationships:


Temperature (F) vs. Latitude
Humidity (%) vs. Latitude
Cloudiness (%) vs. Latitude
Wind Speed (mph) vs. Latitude


Your final notebook must:


Randomly select at least 500 unique (non-repeat) cities based on latitude and longitude.
Perform a weather check on each of the cities using a series of successive API calls.
Include a print log of each city as it's being processed with the city number and city name.
Save both a CSV of all data retrieved and png images for each scatter plot.


As final considerations:


You must complete your analysis using a Jupyter notebook.
You must use the Matplotlib or Pandas plotting libraries.
You must include a written description of three observable trends based on the data.
You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
See Example Solution for a reference on expected format.
